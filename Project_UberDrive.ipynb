# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshk1993/Akshk1993/blob/main/Project_UberDrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uber_df = pd.read_csv("/content/uber-rides-dataset.csv")

# %% [markdown]
# last 10 records of the dataset

# %%
uber_df.tail(10)
# Out:
#              trip_completed_at trip_status ride_hailing_app  \
# 668  April 12, 2018 at 06:05PM   Completed             Uber
# 669  April 13, 2018 at 06:13PM   Completed             Uber
# 670  April 19, 2018 at 10:54AM   Completed             Uber
# 671  April 19, 2018 at 11:55AM   Completed             Uber
# 672  April 23, 2018 at 10:59AM   Completed             Uber
# 673  April 23, 2018 at 12:11PM   Completed             Uber
# 674  April 24, 2018 at 02:58PM   Completed             Uber
# 675  April 26, 2018 at 03:57PM   Completed             Uber
# 676  April 26, 2018 at 05:00PM   Completed             Uber
# 677  April 27, 2018 at 03:05PM   Completed             Uber
#
#                              trip_uid                        driver_uid  \
# 668  a7f621ef27212fa1e54572cad4edde58  adee3059ee7ddf290a7a04d0b9fad61f
# 669  ff2fe36701f7e1a7d60898972df30e56  76412a4ca12da91ef882041c08746f25
# 670  8a531b2bebaa4cb72915b43914bbd97c  0a43af18ab6928e72eaaac52ee58c5ce
# ...

# %% [markdown]
# first 10 records of the dataset

# %%
uber_df.head(10)
# Out:
#          trip_completed_at trip_status ride_hailing_app  \
# 0   May 11, 2015 at 6:55PM   Completed             Uber
# 1   May 11, 2015 at 8:12PM   Completed             Uber
# 2  May 13, 2015 at 11:38AM   Completed             Uber
# 3   May 16, 2015 at 1:44AM   Completed             Uber
# 4   May 16, 2015 at 3:18AM   Completed             Uber
# 5  May 18, 2015 at 11:06AM   Completed             Uber
# 6  May 18, 2015 at 11:08PM   Completed             Uber
# 7   May 19, 2015 at 9:10AM   Completed             Uber
# 8  May 19, 2015 at 12:37PM   Completed             Uber
# 9  May 19, 2015 at 10:33PM   Completed             Uber
#
#                            trip_uid                        driver_uid  \
# 0  ee89076fd9da9bddf5f096b0ca42f8d5  05cfeb269e606247fe9d2b6082942c59
# 1  518be51d403944a03c47e8d1f2c87311  4a4e248742f9d5ff517c5bbbb48d0e54
# 2  6e460cc8a12c3c6568d0d4a67ac58393  cb249a2bd807ca78697b4ed0348c37da
# ...

# %% [markdown]
# number of rows and columns

# %%
uber_df.shape
# Out:
# (678, 45)

# %% [markdown]
# size of the datset

# %%
uber_df.size
# Out:
# 30510

# %% [markdown]
# information of the dataset

# %%
uber_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 678 entries, 0 to 677
# Data columns (total 45 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   trip_completed_at      678 non-null    object
#  1   trip_status            678 non-null    object
#  2   ride_hailing_app       678 non-null    object
#  3   trip_uid               678 non-null    object
#  4   driver_uid             678 non-null    object
#  5   rider_uid              678 non-null    object
#  6   customer               678 non-null    object
#  7   trip_start_time        678 non-null    object
#  8   trip_end_time          678 non-null    object
#  9   trip_time              678 non-null    object
#  10  total_time             678 non-null    object
#  11  wait_time              678 non-null    object
#  12  trip_type              678 non-null    object
#  13  surge_multiplier       643 non-null    float64
# ...

# %% [markdown]
# check missing values

# %%
uber_df.isnull()
# Out:
#      trip_completed_at  trip_status  ride_hailing_app  trip_uid  driver_uid  \
# 0                False        False             False     False       False
# 1                False        False             False     False       False
# 2                False        False             False     False       False
# 3                False        False             False     False       False
# 4                False        False             False     False       False
# ..                 ...          ...               ...       ...         ...
# 673              False        False             False     False       False
# 674              False        False             False     False       False
# 675              False        False             False     False       False
# 676              False        False             False     False       False
# 677              False        False             False     False       False
#
# ...

# %% [markdown]
# summary of the original data

# %%
uber_df.describe()
# Out:
#        surge_multiplier  pickup_lat  pickup_long  dropoff_lat  dropoff_long  \
# count        643.000000  678.000000   678.000000   678.000000    678.000000
# mean           1.011353   59.756784    31.740062    59.758561     31.739366
# std            0.096085    0.800432     6.063872     0.799396      6.062101
# min            1.000000   55.605800    30.168447    55.599648     29.947507
# 25%            1.000000   59.932134    30.364931    59.933576     30.366456
# 50%            1.000000   59.941415    30.366456    59.941415     30.368724
# 75%            1.000000   59.960492    30.420179    59.961987     30.417860
# max            2.900000   60.126500    60.809913    60.126957     60.809916
#
#        rub_usd_exchange_rate   price_usd  distance_kms  temperature_value  \
# count             678.000000  678.000000    678.000000         678.000000
# mean               60.517463    5.061593     10.057788           5.327434
# ...

# %%
uber_df['driver_uid'].unique()
# Out:
# array(['05cfeb269e606247fe9d2b6082942c59',
#        '4a4e248742f9d5ff517c5bbbb48d0e54',
#        'cb249a2bd807ca78697b4ed0348c37da',
#        'd3f73f8151c2e8c34b541f961db7f5fa',
#        '1287d21e6455ee40d4861f6b91c680f4',
#        'fc6b1516376f15c97e508d904505d27a',
#        '1b926e88a8477f7b5d1fad298e00fb11',
#        '439ae2cf8ae38bc24b2f8dbc3f0b987d',
#        '75a4c47c323bcc96ac5849052b19ed5f',
#        '176f50c4249ddc7b086d8997349d9ae5',
#        'e516233997d15dedf0f12878fd231e23',
#        'a81952458c5e4c7b62a0bacf591dd690',
#        'f065223fa83baa7b2e0037f61b8ebac7',
#        'b897afbe685f70aa5114bf4f6a19392b',
#        'ef33153fbce5b15f93d9319528dc598f',
#        'b6584dd094679d58c938511d478169d6',
#        'c85086781a9a41cb76345374fb11360a',
#        'd505ef8cb3f776ca6acccd10b3fdbf78',
#        '97e28e41c95e7cbf1e36d6737d0eeefe',
#        '767a9c87d435285ab26f73a14abbc8d2',
#        '151944a8f9967b3edad02deb712d61f2',
#        'a89bc69e8452fcec3f650b688f6e3473',
# ...

# %%
sns.distplot(uber_df['temperature_value'])
# Out:
# <ipython-input-16-7c040aa5c5ec>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(uber_df['temperature_value'])
# <Axes: xlabel='temperature_value', ylabel='Density'>

# %%
sns.distplot(uber_df['temperature_value'],kde=False)
# Out:
# <ipython-input-19-fda49c777b48>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(uber_df['temperature_value'],kde=False)
# <Axes: xlabel='temperature_value'>

# %%
sns.distplot(uber_df['temperature_value'],kde=False,bins=30)
# Out:
# <ipython-input-20-53e37c2bee7e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(uber_df['temperature_value'],kde=False,bins=30)
# <Axes: xlabel='temperature_value'>

# %%
sns.distplot(uber_df['temperature_value'],kde=False,bins=10)
# Out:
# <ipython-input-21-62144f16042e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(uber_df['temperature_value'],kde=False,bins=10)
# <Axes: xlabel='temperature_value'>
